# %%
#добавить молоточек autopep8 в юпитер:
# conda install -c conda-forge jupyter_contrib_nbextensions
# pip install autopep8
# jupyter contrib nbextension install --user





import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 50) # показывать больше строк
pd.set_option('display.max_columns', 50) # показывать больше колонок

cacao = pd.read_csv('cacao_flavors.csv')
cacao.columns=['bar_id', 'company','specific_origin', 'ref', 'review_date','cocoa_percent', 'company_location', 'rating', 'bean_type',
       'broad_origin']

print(cacao.bar_id.nunique())
plt.plot(cacao.bar_id)
cacao.drop(['bar_id'], inplace = True, axis = 1) #удалить, не нужен 

display(cacao.head(10))
cacao.info()
# Out:
# 1795
#     company specific_origin   ref  review_date cocoa_percent company_location  \
# 0  A. Morin     Agua Grande  1876         2016           63%           France
# 1  A. Morin           Kpime  1676         2015           70%           France
# 2  A. Morin          Atsane  1676         2015          670%           France
# 3  A. Morin           Akata  1680         2015           70%           France
# 4  A. Morin          Quilla  1704         2015           70%           France
# 5  A. Morin        Carenero  1315         2014           70%           France
# 6  A. Morin            Cuba  1315         2014           70%           France
# 7  A. Morin    Sur del Lago  1315         2014           70%           France
# 8            Puerto Cabello  1319         2014           70%           France
# 9  A. Morin         Pablino  1319         2014           70%           France
#
#    rating bean_type broad_origin
# 0   11.50               Sao Tome
# 1    2.75                   Togo
# 2    3.00                   Togo
# 3    3.50                   Togo
# 4    3.50                   Peru
# 5    2.75   Criollo    Venezuela
# 6    3.50                   Cuba
# 7   11.50   Criollo    Venezuela
# 8    3.75   Criollo    Venezuela
# 9    4.00                   Peru
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           1795 non-null   object
#  1   specific_origin   1795 non-null   object
#  2   ref               1795 non-null   int64
#  3   review_date       1795 non-null   int64
#  4   cocoa_percent     1795 non-null   object
#  5   company_location  1795 non-null   object
#  6   rating            1795 non-null   float64
#  7   bean_type         1794 non-null   object
#  8   broad_origin      1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
display(pd.DataFrame(cacao.specific_origin.value_counts()))
cacao.specific_origin=cacao.specific_origin.apply(lambda x: None if (type(x)!=str) or  (x.strip() == '') else x)
print("Значений, встретившихся в столбце более 10 раз:"#Число 10 взято для ориентира, можно брать другое
      , (cacao.specific_origin.value_counts()>10).sum())



cacao.company = cacao.company.apply(lambda x: None if (type(x)!=str) or  (x.strip() == '') else x)
display(pd.DataFrame(cacao.company.value_counts()))
print("Значений, встретившихся в столбце более 10 раз:"#Число 10 взято для ориентира, можно брать другое
      , (cacao.company.value_counts()>10).sum())
cacao.loc[:, ['company']].info()
# Out:
#                                        specific_origin
#                                                     58
# Madagascar                                          55
# Peru                                                44
# Ecuador                                             39
# Dominican Republic                                  33
# ...                                                ...
# Madagascar, Ambolikapiky P.                          1
# O'ahu, N. Shore, Waialua E., Kakoleka                1
# Mahali, Kasai                                        1
# Los Rios, Puerto Romero, Equateur                    1
# Maya Mtn, Batch 18, Heirloom                         1
#
# [1013 rows x 1 columns]
# Значений, встретившихся в столбце более 10 раз: 15
#                                    company
# Soma                                    45
# Bonnat                                  26
# Fresco                                  26
# Pralus                                  25
# Domori                                  22
# ...                                    ...
# Cacaosuyo (Theobroma Inversiones)        1
# Jacque Torres                            1
# Monarque                                 1
# Durand                                   1
# Cacao Arabuco                            1
#
# [407 rows x 1 columns]
# Значений, встретившихся в столбце более 10 раз: 30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   company  1696 non-null   object
# dtypes: object(1)
# memory usage: 14.1+ KB

# %%
cacao.ref.hist()
cacao.ref.describe()
# Out:
# count    1795.000000
# mean     1035.904735
# std       552.886365
# min         5.000000
# 25%       576.000000
# 50%      1069.000000
# 75%      1502.000000
# max      1952.000000
# Name: ref, dtype: float64

# %%
cacao.review_date.hist()
cacao.review_date.describe()
# Out:
# count    1795.000000
# mean     2012.325348
# std         2.927210
# min      2006.000000
# 25%      2010.000000
# 50%      2013.000000
# 75%      2015.000000
# max      2017.000000
# Name: review_date, dtype: float64

# %%
def displayvibros(strstr,df):
    isis=0;
    IRQ=df.quantile(.75, interpolation='midpoint')-df.quantile(.25, interpolation='midpoint')
    for qq in df:
        if qq<df.quantile(.25, interpolation='midpoint')-1.5*IRQ or  qq>df.quantile(.75, interpolation='midpoint')+1.5*IRQ :
            print(strstr,qq)
            isis=isis+1
    print(strstr,isis)
            
displayvibros("review_date",cacao.review_date)
# Out:
# review_date 0

# %%
cacao.cocoa_percent
cacao.cocoa_percent = cacao.cocoa_percent.apply(lambda x: float(x.replace('%', '')))
cacao.cocoa_percent.hist()
cacao.cocoa_percent.describe()
# Out:
# count    1795.000000
# mean       75.932312
# std        44.475981
# min        42.000000
# 25%        70.000000
# 50%        70.000000
# 75%        75.000000
# max       682.000000
# Name: cocoa_percent, dtype: float64

# %%
IQR = cacao.cocoa_percent.quantile(0.75) - cacao.cocoa_percent.quantile(0.25)
perc25 = cacao.cocoa_percent.quantile(0.25)
perc75 = cacao.cocoa_percent.quantile(0.75)
 
print(
'25-й перцентиль: {},'.format(perc25),
'75-й перцентиль: {},'.format(perc75),
"IQR: {}, ".format(IQR),
"Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
 
cacao.cocoa_percent.loc[cacao.cocoa_percent.between(
perc25 - 1.5*IQR,
perc75 + 1.5*IQR)].hist(bins = 16, range = (40, 100), label = 'IQR')
 
cacao.cocoa_percent.loc[cacao.cocoa_percent <= 100].hist(
alpha = 0.5, bins = 16, range = (40, 100), label = 'Здравый смысл')
 
plt.legend();
cacao = cacao.loc[cacao.cocoa_percent <= 100]
# Out:
# 25-й перцентиль: 70.0, 75-й перцентиль: 75.0, IQR: 5.0,  Границы выбросов: [62.5, 82.5].

# %%
display(pd.DataFrame(cacao.company_location.value_counts()))
print("Значений, встретившихся в столбце более 10 раз:", (cacao.company_location.value_counts()>10).sum())
cacao.loc[:, ['company_location']].info()
# Out:
#                 company_location
# U.S.A.                       756
# France                       155
# Canada                       124
# U.K.                          94
# Italy                         63
# ...                          ...
# Eucador                        1
# Suriname                       1
# Czech Republic                 1
# Niacragua                      1
# India                          1
#
# [60 rows x 1 columns]
# Значений, встретившихся в столбце более 10 раз: 22
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1776 entries, 0 to 1794
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company_location  1776 non-null   object
# dtypes: object(1)
# memory usage: 27.8+ KB

# %%
cacao.rating
cacao.rating.hist()
cacao.rating.describe()
# Out:
# count    1776.000000
# mean        3.425816
# std         1.759007
# min         1.000000
# 25%         3.000000
# 50%         3.250000
# 75%         3.500000
# max        19.750000
# Name: rating, dtype: float64

# %%
IQR = cacao.rating.quantile(0.75) - cacao.rating.quantile(0.25)
perc25 = cacao.rating.quantile(0.25)
perc75 = cacao.rating.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75), "IQR: {}, ".format(IQR), "Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
 
cacao.rating.loc[cacao.rating.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 10, range = (0, 10), label = 'IQR')
 
plt.legend();
cacao = cacao.loc[cacao.rating.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)]
# Out:
# 25-й перцентиль: 3.0, 75-й перцентиль: 3.5, IQR: 0.5,  Границы выбросов: [2.25, 4.25].

# %%
cacao.bean_type = cacao.bean_type.astype(str).apply(lambda x: None if x.strip() == '' else x)
display(pd.DataFrame(cacao.bean_type.value_counts()))
print("Значений, встретившихся в столбце более 10 раз:", (cacao.bean_type.value_counts()>10).sum())
print("Уникальных значений:", cacao.bean_type.nunique())
cacao.loc[:, ['bean_type']].info()
# Out:
#                           bean_type
# Trinitario                      401
# Criollo                         147
# Forastero                        81
# Forastero (Nacional)             50
# Criollo, Trinitario              37
# Blend                            36
# Forastero (Arriba)               30
# Criollo (Porcelana)              10
# Trinitario, Criollo               9
# Forastero (Parazinho)             8
# Forastero (Arriba) ASS            5
# Matina                            3
# EET                               3
# Beniano                           3
# Nacional (Arriba)                 3
# Forastero (Catongo)               2
# Amazon mix                        2
# Criollo, Forastero                2
# Criollo (Ocumare 61)              2
# Trinitario (85% Criollo)          2
# Amazon, ICS                       2
# Trinitario, Forastero             2
# Nacional                          2
# Criollo (Amarru)                  2
# Forastero (Arriba) ASSS           1
# Trinitario (Amelonado)            1
# Trinitario, TCGA                  1
# Forastero (Amelonado)             1
# Trinitario (Scavina)              1
# Criollo (Ocumare 77)              1
# Forastero, Trinitario             1
# Criollo (Ocumare 67)              1
# Blend-Forastero,Criollo           1
# nan                               1
# Criollo (Ocumare)                 1
# Trinitario, Nacional              1
# CCN51                             1
# Forastero(Arriba, CCN)            1
# Amazon                            1
# Criollo, +                        1
# Criollo (Wild)                    1
# Значений, встретившихся в столбце более 10 раз: 7
# Уникальных значений: 41
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1690 entries, 1 to 1794
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bean_type  861 non-null    object
# dtypes: object(1)
# memory usage: 26.4+ KB

# %%
len(cacao.bean_type)
# Out:
# 1690

# %%
qq=0
for i in range(len(cacao.bean_type)):
    x=cacao.bean_type.iloc[i]
    if pd.isnull(x) or x == 'nan' or '(' not in x:
        pass
    else :
        qq=qq+1
        print(x)
        print(x[:x.find('(')].strip())
        if qq>10:
            break
# Out:
# Forastero (Arriba)
# Forastero
# Forastero (Arriba)
# Forastero
# Forastero (Nacional)
# Forastero
# Criollo (Porcelana)
# Criollo
# Trinitario (85% Criollo)
# Trinitario
# Trinitario (85% Criollo)
# Trinitario
# Forastero (Catongo)
# Forastero
# Forastero (Parazinho)
# Forastero
# Forastero (Parazinho)
# Forastero
# Forastero (Parazinho)
# Forastero
# Forastero (Parazinho)
# Forastero

# %%
cacao.bean_type = cacao.bean_type.apply(lambda x: None if pd.isnull(x) else None if x == 'nan' 
                      else x if '(' not in x else x[:x.find('(')].strip())
display(pd.DataFrame(cacao.bean_type.value_counts()))
print("Значений, встретившихся в столбце более 10 раз:", (cacao.bean_type.value_counts()>10).sum())
print("Уникальных значений:", cacao.bean_type.nunique())
cacao.loc[:, ['bean_type']].info()
# Out:
#                          bean_type
# Trinitario                     405
# Forastero                      179
# Criollo                        165
# Criollo, Trinitario             37
# Blend                           36
# Trinitario, Criollo              9
# Nacional                         5
# Matina                           3
# Beniano                          3
# EET                              3
# Amazon, ICS                      2
# Criollo, Forastero               2
# Amazon mix                       2
# Trinitario, Forastero            2
# Blend-Forastero,Criollo          1
# CCN51                            1
# Criollo, +                       1
# Forastero, Trinitario            1
# Trinitario, Nacional             1
# Trinitario, TCGA                 1
# Amazon                           1
# Значений, встретившихся в столбце более 10 раз: 5
# Уникальных значений: 21
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1690 entries, 1 to 1794
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bean_type  860 non-null    object
# dtypes: object(1)
# memory usage: 26.4+ KB

# %%
for i in range(len(cacao.broad_origin)):
    x=cacao.broad_origin.iloc[i]
    if pd.isnull(x) or x == 'nan' or x == '':
        print(x)
# Out:
# nan

# %%
cacao.broad_origin = cacao.broad_origin.apply(lambda x: None if pd.isnull(x) else None if x == 'nan' 
                      else None if x == '' else x)
display(pd.DataFrame(cacao.broad_origin.value_counts()))
print("Значений, встретившихся в столбце более 10 раз:", (cacao.broad_origin.value_counts()>10).sum())
print("Уникальных значений:", cacao.broad_origin.nunique())
cacao.loc[:, ['broad_origin']].info()
# Out:
#                       broad_origin
# Venezuela                      202
# Ecuador                        179
# Peru                           159
# Madagascar                     138
# Dominican Republic             135
# ...                            ...
# Ven., Trinidad, Mad.             1
# Peru, Dom. Rep                   1
# PNG, Vanuatu, Mad                1
# Martinique                       1
# Tobago                           1
#
# [97 rows x 1 columns]
# Значений, встретившихся в столбце более 10 раз: 26
# Уникальных значений: 97
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1690 entries, 1 to 1794
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   broad_origin  1689 non-null   object
# dtypes: object(1)
# memory usage: 26.4+ KB

# %%
df=cacao.broad_origin.value_counts().reset_index()
display(df)
# for i in range(len(df)):
#     x=df.iloc[i]

print(df.sort_values(by='index').to_string())
# Out:
#                                index  broad_origin
# 0                          Venezuela           202
# 1                            Ecuador           179
# 2                               Peru           160
# 3                   DomincanRepublic           159
# 4                         Madagascar           138
# ..                               ...           ...
# 88                 Ecuador,CostaRica             1
# 89  Peru,Madagascar,DomincanRepublic             1
# 90                           Nigeria             1
# 91                      Peru,Ecuador             1
# 92                Madagascar,Ecuador             1
#
# [93 rows x 2 columns]
#                                                         index  broad_origin
# 76                                     Africa,Carribean,C.Am.             1
# 42                                                  Australia             3
# 9                                                      Belize            49
# 8                                                     Bolivia            53
# 6                                                      Brazil            57
# 74                                                      Burma             1
# 87                                                   Cameroon             1
# 29                                                  Carribean             8
# 41                                        CentralandS.America             4
# 12                                                   Colombia            38
# 43                                           Colombia,Ecuador             3
# 25                                                      Congo            10
# 69                                         CostRica,Venezuela             1
# 13                                                  CostaRica            36
# 24                                                       Cuba            11
# 3                                            DomincanRepublic           159
# 66                                      DomincanRepublic,Bali             1
# 73                              DomincanRepublic,Ecuador,Peru             1
# 57                                DomincanRepublic,Madagascar             1
# 1                                                     Ecuador           179
# 88                                          Ecuador,CostaRica             1
# 70                          Ecuador,Madagascar,PapuaNewGuinea             1
# 47                                                 ElSalvador             2
# 28                                                       Fiji             8
# 55                                                      Gabon             1
# 15                                                      Ghana            31
# 84                                     Ghana,DomincanRepublic             1
# 22                                                    Grenada            16
# 82             Grenada,PapuaNewGuinea,Hawaii,Haiti,Madagascar             1
# 19                                                  Guatemala            26
# 78  Guatemala,DomincanRepublic,Peru,Madagascar,PapuaNewGuinea             1
# 27                                                      Haiti             9
# 18                                                     Hawaii            26
# 23                                                   Honduras            15
# 37                                                      India             4
# 21                                                  Indonesia            16
# 79                                            Indonesia,Ghana             1
# 36                                                 IvoryCoast             5
# 20                                                    Jamaica            18
# 46                                                    Liberia             3
# 4                                                  Madagascar           138
# 92                                         Madagascar,Ecuador             1
# 72                             Madagascar,Java,PapuaNewGuinea             1
# 45                                           Madagascarlaysia             3
# 59                                         Madagascarrtinique             1
# 17                                                     Mexico            28
# 7                                                   Nicaragua            57
# 90                                                    Nigeria             1
# 30                                                     Panama             7
# 10                                             PapuaNewGuinea            41
# 80                          PapuaNewGuinea,Vanuatu,Madagascar             1
# 2                                                        Peru           160
# 65                                                Peru,Belize             1
# 53                                      Peru,DomincanRepublic             1
# 91                                               Peru,Ecuador             1
# 71                                     Peru,Ecuador,Venezuela             1
# 75                                            Peru,Madagascar             1
# 89                           Peru,Madagascar,DomincanRepublic             1
# 35                                                Philippines             5
# 86                                                   Principe             1
# 40                                                 PuertoRico             4
# 52                                                      Samoa             2
# 26                                                    SaoTome             9
# 34                                           SaoTome,Principe             6
# 39                                             SolomonIslands             4
# 44                                               SouthAmerica             3
# 83                                        SouthAmerica,Africa             1
# 51                                                   SriLanka             2
# 33                                                   St.Lucia             6
# 68                                                   Suriname             1
# 16                                                   Tanzania            30
# 77                                                     Tobago             1
# 48                                                       Togo             2
# 14                                                   Trinidad            32
# 62                                           Trinidad,Ecuador             1
# 50                                            Trinidad,Tobago             2
# 67                                            Trinidad-Tobago             1
# 32                                                     Uganda             7
# 31                                                    Vanuatu             7
# 0                                                   Venezuela           202
# 60                        Venezuela,Africa,Brasil,Peru,Mexico             1
# 61                         Venezuela,Bolivia,DomincanRepublic             1
# 54                                        Venezuela,Carribean             1
# 63                                 Venezuela,DomincanRepublic             1
# 85                           Venezuela,Ecuador,Peru,Nicaragua             1
# 49                                            Venezuela,Ghana             2
# 56                                             Venezuela,Java             1
# 81                                         Venezuela,Trinidad             1
# 58                                 Venezuela,Trinidad,Ecuador             1
# 64                              Venezuela,Trinidad,Madagascar             1
# 11                                                    Vietnam            38
# 38                                                 WestAfrica             4
# 5                                                                        59

# %%
def fix_countries(x):
    if pd.isnull(x):
        return x
    if x == 'nan':
        return None
    x = x.replace(' ', '')
    x = x.replace('/', ',') # Venezuela/ Ghana
    x = x.replace('&', ',')
    if '(' in x:
        x = x[:x.find('(')] #Peru(SMartin,Pangoa,nacional)
    x = x.replace('Guat.', 'Guatemala')
    
    if 'Ven' in x and 'Venezuela' not in x:
        x = x.replace('Venez', 'Venezuela') #Venez,Africa,Brasil,Peru,Mex
        x = x.replace('Ven,', 'Venezuela,') #Ven, Trinidad, Ecuador
        x = x.replace('Ven.', 'Venezuela') #Ven., Trinidad, Mad.
        if 'Ven' in x and 'Venezuela' not in x:
            x = x.replace('Ven', 'Venezuela')
        
    x = x.replace('Dom.Rep.', 'DomincanRepublic')
    x = x.replace('DR', 'DomincanRepublic')
    x = x.replace('Dom.Rep', 'DomincanRepublic')
    x = x.replace('D.R.', 'DomincanRepublic')
    x = x.replace('DominicanRep.', 'DomincanRepublic')
    x = x.replace('Domin.Rep', 'DomincanRepublic')
    x = x.replace('Domin.Re', 'DomincanRepublic')
    x = x.replace('DominicanRepublic', 'DomincanRepublic')

    if 'Jam' in x and 'Jamaica' not in x:
        x = x.replace('Jam', 'Jamaica')
        
    if 'Mad.' in x and 'Madagascar' not in x:
        x = x.replace('Mad.', 'Madagascar')
    elif 'Mad' in x and 'Madagascar' not in x:
        x = x.replace('Mad', 'Madagascar')
    elif 'Ma' in x and 'Madagascar' not in x:
        x = x.replace('Ma', 'Madagascar')
        
    if 'Hait' in x and 'Haiti' not in x:
        x = x.replace('Hait', 'Haiti')
        
    if 'Per' in x and 'Peru'  not in x:
        x = x.replace('Per', 'Peru')
    
    x = x.replace('Nic.', 'Nicaragua')

    x = x.replace('Gre.', 'Grenada')
    
    x = x.replace('PNG', 'PapuaNewGuinea')
    
    if 'Mex' in x and 'Mexico' not in x:
        x = x.replace('Mex', 'Mexico')
        
    x = x.replace('Haw.', 'Hawaii')
    
    x = x.replace('Ecuad.', 'Ecuador')
    x = x.replace('Ecu.', 'Ecuador')
    
    return x
cacao.broad_origin = cacao.broad_origin.apply(fix_countries)

# %%
display(pd.DataFrame(cacao.broad_origin.value_counts()))
print('Значений, упомянутых более 10 раз:', (cacao.broad_origin.value_counts()>10).sum())
print("Уникальных значений:", cacao.broad_origin.nunique())
cacao.loc[:, ['broad_origin']].info()
# Out:
#                                   broad_origin
# Venezuela                                  202
# Ecuador                                    179
# Peru                                       160
# DomincanRepublic                           159
# Madagascar                                 138
# ...                                        ...
# Ecuador,CostaRica                            1
# Peru,Madagascar,DomincanRepublic             1
# Nigeria                                      1
# Peru,Ecuador                                 1
# Madagascar,Ecuador                           1
#
# [93 rows x 1 columns]
# Значений, упомянутых более 10 раз: 25
# Уникальных значений: 93
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1690 entries, 1 to 1794
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   broad_origin  1689 non-null   object
# dtypes: object(1)
# memory usage: 26.4+ KB

# %%
sns.pairplot(cacao, kind = 'reg')

# %%
cacao.corr()
# Out:
#                     ref  review_date  cocoa_percent    rating
# ref            1.000000     0.984913       0.083765  0.016189
# review_date    0.984913     1.000000       0.086523  0.006703
# cocoa_percent  0.083765     0.086523       1.000000 -0.078156
# rating         0.016189     0.006703      -0.078156  1.000000

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize = (14, 4))
    sns.boxplot(x=column, y='rating', 
                data=cacao.loc[cacao.loc[:, column].isin(cacao.loc[:, column].value_counts().index[:10])],
               ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()
for col in ['company', 'specific_origin', 'company_location', 'bean_type', 'broad_origin']:
    get_boxplot(col)

# %%
cols = cacao.loc[:, 'company'].value_counts().index[:10]
display(cols)
combinations_all = list(combinations(cols, 2))
display(combinations_all)
# Out:
# Index(['Soma', 'Bonnat', 'Fresco', 'Pralus', 'Domori', 'Valrhona', 'Arete',
#        'A. Morin', 'Guittard', 'Mast Brothers'],
#       dtype='object')
# [('Soma', 'Bonnat'),
#  ('Soma', 'Fresco'),
#  ('Soma', 'Pralus'),
#  ('Soma', 'Domori'),
#  ('Soma', 'Valrhona'),
#  ('Soma', 'Arete'),
#  ('Soma', 'A. Morin'),
#  ('Soma', 'Guittard'),
#  ('Soma', 'Mast Brothers'),
#  ('Bonnat', 'Fresco'),
#  ('Bonnat', 'Pralus'),
#  ('Bonnat', 'Domori'),
#  ('Bonnat', 'Valrhona'),
#  ('Bonnat', 'Arete'),
#  ('Bonnat', 'A. Morin'),
#  ('Bonnat', 'Guittard'),
#  ('Bonnat', 'Mast Brothers'),
#  ('Fresco', 'Pralus'),
#  ('Fresco', 'Domori'),
#  ('Fresco', 'Valrhona'),
#  ('Fresco', 'Arete'),
#  ('Fresco', 'A. Morin'),
#  ('Fresco', 'Guittard'),
#  ('Fresco', 'Mast Brothers'),
#  ('Pralus', 'Domori'),
#  ('Pralus', 'Valrhona'),
#  ('Pralus', 'Arete'),
#  ('Pralus', 'A. Morin'),
#  ('Pralus', 'Guittard'),
#  ('Pralus', 'Mast Brothers'),
#  ('Domori', 'Valrhona'),
#  ('Domori', 'Arete'),
#  ('Domori', 'A. Morin'),
#  ('Domori', 'Guittard'),
#  ('Domori', 'Mast Brothers'),
#  ('Valrhona', 'Arete'),
#  ('Valrhona', 'A. Morin'),
#  ('Valrhona', 'Guittard'),
#  ('Valrhona', 'Mast Brothers'),
#  ('Arete', 'A. Morin'),
#  ('Arete', 'Guittard'),
#  ('Arete', 'Mast Brothers'),
#  ('A. Morin', 'Guittard'),
#  ('A. Morin', 'Mast Brothers'),
#  ('Guittard', 'Mast Brothers')]

# %%
def get_stat_dif(column):
    cols = cacao.loc[:, column].value_counts().index[:10]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(cacao.loc[cacao.loc[:, column] == comb[0], 'rating'], 
                        cacao.loc[cacao.loc[:, column] == comb[1], 'rating']).pvalue \
            <= 0.05/len(combinations_all): # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break
for col in ['company', 'specific_origin', 'company_location', 'bean_type', 'broad_origin']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки company
# Найдены статистически значимые различия для колонки specific_origin
# Найдены статистически значимые различия для колонки company_location

# %%
cacao_for_model = cacao.loc[:, ['company', 'specific_origin', 'company_location', 'review_date', 'cocoa_percent']]
cacao_for_model.head()
# Out:
#     company specific_origin company_location  review_date  cocoa_percent
# 1  A. Morin           Kpime           France         2015           70.0
# 3  A. Morin           Akata           France         2015           70.0
# 4  A. Morin          Quilla           France         2015           70.0
# 5  A. Morin        Carenero           France         2014           70.0
# 6  A. Morin            Cuba           France         2014           70.0
